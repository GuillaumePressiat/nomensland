# %%
from nomensland import *
import pprint
pp = pprint.PrettyPrinter(depth=2, indent = 4)

# %%
pp.pprint(get_liste('chip'))
# Out:
# {   'abrege': ['chip'],
#     'actes': ['HPLB003'],
#     'auteur': ['DGOS - ATIH'],
#     'date_saisie': ['2017-04-23T22:00:00Z'],
#     'nom': ['Chimiothérapie hyperthermique intra-péritonéale (CHIP)'],
#     'thematique': ['Recours Exceptionnel'],
#     'timestamp': [1493282250]}

# %%
pp.pprint(get_liste('GM01'))
# Out:
# {   'abrege': ['GM01'],
#     'actes': ['FAFA001', 'FAFA002', 'FAFA008', 'FAFA013'],
#     'auteur': ['ARS'],
#     'date_saisie': ['2017-06-18T22:00:00Z'],
#     'nom': ['Adénoïdectomies'],
#     'thematique': ['Chir ambu : 55 GM'],
#     'timestamp': [1497823200]}

# %%
get_table('ccam_actes').head(10)
# Out:
#       code compatibilite_sexe  date_debut date_fin  \
# 0  AAFA001                  0  2005-03-01      NaN
# 1  AAFA002                  0  2005-03-01      NaN
# 2  AAFA003                  0  2005-03-01      NaN
# 3  AAFA004                  0  2005-03-01      NaN
# 4  AAFA005                  0  2005-03-01      NaN
# 5  AAFA006                  0  2005-03-01      NaN
# 6  AAFA007                  0  2005-03-01      NaN
# 7  AAFA008                  0  2005-03-01      NaN
# 8  AAGA900                  0  2005-03-01      NaN
# 9  AAGB001                  0  2005-03-01      NaN
#
#                                        libelle_court  \
# 0          exérèse T. intraparench cervelet craniot.
# 1           exérèse T. intraparench cerveau craniot.
# 2                   exérèse lés. tr. céréb. craniot.
# 3                      hémisphérectomie fct craniot.
# 4  exérèse lés. corps calleux fornix/septum pellu...
# 5  résec. parenchyme céréb. pr infarctus expansif...
# ...

# %%
get_table('orpha')[['id', 'name', 'icd10', 'umls', 'mesh', 'synonymes']].head(10)
# Out:
#      id                                               name  icd10  \
# 0  3555  Déficit en 3-hydroxyacyl-CoA déshydrogénase de...  E71.3
# 1  3297        Déficit en 3-méthylcrotonyl-CoA carboxylase  E71.1
# 2  1242                                        Syndrome 3C  Q87.8
# 3   335                                    Syndrome 47,XYY  Q98.5
# 4   390                                       Tétrasomie X  Q97.1
# 5  1056                                   Syndrome 48,XXYY  Q98.8
# 6   378                                       Pentasomie X  Q97.1
# 7   771   Déficit en 6-pyruvoyl-tétrahydroptérine synthase  E70.1
# 8   252                               Abêtalipoprotéinémie  E78.6
# 9   148                                     Achondroplasie  Q77.4
#
#                   umls               mesh  \
# 0  C0342786 ; C1969443                NaN
# 1             C0268600            C535308
# 2             C0796137            C535313
# 3  C3266843 ; C0043379  C535317 ; D014997
# ...

# %%
df = get_table('cim')
df[(df.anseqta == '2018')].head(10)
# Out:
#       anseqta  code                lib_court  \
# 68561    2018   A53     SYPHILIS, NCA OU SAI
# 69373    2018  E612     CARENCE EN MAGNESIUM
# 70266    2018  E613     CARENCE EN MANGANESE
# 71617    2018  E614        CARENCE EN CHROME
# 72005    2018  E615     CARENCE EN MOLYBDENE
# 72378    2018  E616      CARENCE EN VANADIUM
# 72412    2018  G433        MIGRAINE COMPLIQ.
# 75021    2018  G438           MIGRAINES, NCA
# 75525    2018  G439            MIGRAINE, SAI
# 75910    2018   G92  ENCEPHALOPATHIE TOXIQUE
#
#                                  lib_long tr
# 68561  Syphilis, autres et sans précision  3
# 69373                Carence en magnésium  0
# 70266                Carence en manganèse  0
# 71617                   Carence en chrome  0
# 72005                Carence en molybdène  0
# 72378                 Carence en vanadium  0
# 72412                 Migraine compliquée  0
# 75021                    Autres migraines  0
# 75525            Migraine, sans précision  0
# ...

# %%
get_table('csarr_acte_ref').head(10)
# Out:
#   anseqta appareillage     code collectif dedie  \
# 0    2017          NaN  ALQ+183       NaN   oui
# 1    2017          NaN  ALQ+065       NaN   oui
# 2    2017          NaN  ALQ+110       NaN   oui
# 3    2017          NaN  ALQ+247       NaN   oui
# 4    2017          NaN  ALQ+137       NaN   oui
# 5    2017          NaN  ALQ+250       NaN   oui
# 6    2017          NaN  ALQ+111       NaN   oui
# 7    2017          NaN  ALQ+176       NaN   oui
# 8    2017          NaN  ALQ+001       NaN   oui
# 9    2017          NaN  ALQ+285       NaN   oui
#
#                                              libelle non_dedie  \
# 0  Évaluation analytique initiale de fonction cog...       non
# 1  Évaluation analytique intermédiaire ou ciblée ...       non
# 2  Évaluation analytique finale de fonction cogni...       non
# 3  Évaluation globale initiale de plusieurs fonct...       non
# 4  Évaluation globale intermédiaire de plusieurs ...       non
# ...
